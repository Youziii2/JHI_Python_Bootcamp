# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5
# Out:
# 20.0

# %% [markdown]
# Integer and float. Will evaluate to float.

# %%
9 / 2
# Out:
# 4.5

# %% [markdown]
# Integer. Will evaluate to float.

# %%
1.5 * 2 >= 7 - 3
# Out:
# False

# %% [markdown]
# Integer and float. Will produce a boolean result.

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4
# Out:
# 46

# %% [markdown]
# 6 * 3, 7 * 4, and then adding the two results.

# %%
5 - 2 * 3 ** 4
# Out:
# -157

# %% [markdown]
# 3 ** 4, 2 * (3**4), 5 - the result of the previous step.

# %%
(5 - 2) * 3 ** 4
# Out:
# 243

# %% [markdown]
# (5 - 2), 3 ** 4, and then (5 - 2) * (3 ** 4)

# %%
5 + 2 >= 3 * 4
# Out:
# False

# %% [markdown]
# 3 * 4, 5 + 2, >=

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# No error

# %%
84 *= 0.5 / 7
# Out:
#   Cell In[9], line 1
#     84 *= 0.5 / 7
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %% [markdown]
# Error. *= is not a valid syntax.

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# No Error.

# %%
5 * 3 = weight
# Out:
#   Cell In[11], line 1
#     5 * 3 = weight
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# Error. If want to name a variable, should do: weight = 5 * 3

# %%
73 / -----------5
# Out:
# -14.6

# %% [markdown]
# No error.

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6

if isinstance(value, str):
    print('It is valid.')
else:
    raise TypeError('value must be a string')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       2
#       3 if isinstance(value, str):
#       4     print('It is valid.')
#       5 else:
# ----> 6     raise TypeError('value must be a string')
#
# TypeError: value must be a string

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])

# %% [markdown]
# Index error. Out of range.

# %%
fullName = "Taylor Swift"
print(full_name)

# %% [markdown]
# full_name is not defined.

# %%
2 + '2' + 4

# %% [markdown]
# You can not add integers and strings together.

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
def convert_km_m(km: float) -> float:
    '''Return the converted mile from kilometers'''
    mile = km / 1.6
    return mile

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)


### Answer: 3
# Out:
# 3

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    ''
    >>> repeat('yesnomaybe', 3)
    'yesnomaybeyesnomaybeyesnomaybe'
    '''
    output = string * num

    return output

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    cleaned = number.replace('(', '').replace(')', '').replace('-', '').replace(' ', '')
    return cleaned[:3] == '416'
